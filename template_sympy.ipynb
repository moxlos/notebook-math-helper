# %% [markdown]
# # Symbolic Math Helper
#
# An interactive, tabbed helper for symbolic mathematics, built on [SymPy](https://www.sympy.org/).
# Run the cell below to launch the UI, then use the tabs for common operations — or keep
# using the rest of this notebook for your own free-form calculations.
#
# **Tips**
# - `^` works as a power operator and implicit multiplication is allowed (e.g. `2x` means `2*x`).
# - Every result shows the equivalent SymPy code in a collapsible panel.
# - Symbols you declare in the **Symbols** tab (with assumptions) are picked up by every tab.

# %%
from sympy_helper import SympyHelper

helper = SympyHelper()  # renders the tabbed UI

# %% [markdown]
# ---
# ## Scratch space
#
# Use the cells below for your own calculations. The common symbols
# (`x, y, z, t, n, k, a, b, c, s, r, u, v, w`) and all of SymPy are already available:

# %%
from sympy import *
x, y, z, t = symbols('x y z t')

# e.g.
integrate(sin(x)**2, x)
